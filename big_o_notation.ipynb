# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %% [markdown]
#  Title your chart "Big O Notation"
#  Label your x axis "Elements"
#  Label your y axis "Operations"
#  Label your curves or make a legend for the curves
#  Use LaTex notation where possible
#
#  y=0n+1 and label the curve "O(1)"
#  y=log(n) and label the curve "O(log n)"
#  y=n and label the curve "O(n)"
#  y=n∗log(n) and label it "O(n log n)"
#  y=n^2 and label it "O(n^2)"
#  y=2^n and label it "O(2^n)"
#  y=n! and label it "O(n!)"
#  y=n^n and label it "O(n^n)"

# %%
x = np.linspace(1,10,10)
y1=0*x+1
y2=np.log2(x)
y3=x
y4=x*np.log2(x)
y5=x**2
y6=2**x
y7=[np.math.factorial(i)for i in x]
y8=x**x
fig,ax = plt.subplots()
ax.plot(x,y1,label='$0(1)$')
ax.plot(x,y2,label='$0(\log n)$')
ax.plot(x,y3,label='$0(n)$')
ax.plot(x,y4,label='$0(n\lg n)$')
ax.plot(x,y5,label='$0(n^2)$')
ax.plot(x,y6,label='$0(2^n)$')
ax.plot(x,y7,label='$0(n!)$')
ax.plot(x,y8,label='$0(n^n)$')
ax.set_title('Big_O_Notation')
ax.set_xlabel('Elements')
ax.set_ylabel('Operations')
ax.legend()
plt.show()
# Out:
# /var/folders/lt/y6xmh16d01v7kft3lkkslw4h0000gn/T/ipykernel_50441/897512941.py:8: DeprecationWarning: Using factorial() with floats is deprecated
#   y7=[np.math.factorial(i)for i in x]
